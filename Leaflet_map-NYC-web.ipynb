# %% [markdown]
# <img src = "https://upload.wikimedia.org/wikipedia/commons/3/32/Earth_rotation.gif" align = right width = 150 height = 450><a id=1></a>
# <h2> Mapping in Python</h2>
# <h1 align = left> A project in heatmapping NYC arrest data using Python...</h1>
# <h3> Amelia Ingram </h3><br>
#
# This project was inspired by a couple [sources](#7):  first, a GeoPython course by Henrikki Tenkanen and George Pipis' blog post on creating heatmaps.  Just for a frame of reference, I just finished my first Python course and won't be able to take data visualization until next year, but wanted to attempt to learn some mapping in the meanwhile with some NYC open data.  (By the way, this is also my first attempt with going "off road" out of a guided course).  The following is the result of my exploration of this technique... </p>

# %%
# Install a pip package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install streamlit-folium #leaflet visualization
# Out:
# Collecting streamlit-folium
#   Downloading streamlit_folium-0.4.0-py3-none-any.whl (4.1 kB)
# Collecting streamlit>=0.79
#   Downloading streamlit-1.5.0-py2.py3-none-any.whl (9.7 MB)
#      |████████████████████████████████| 9.7 MB 1.2 MB/s eta 0:00:01
# Requirement already satisfied: folium>=0.11 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from streamlit-folium) (0.12.1.post1)
# Requirement already satisfied: numpy in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from folium>=0.11->streamlit-folium) (1.20.1)
# Requirement already satisfied: jinja2>=2.9 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from folium>=0.11->streamlit-folium) (2.11.3)
# Requirement already satisfied: branca>=0.3.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from folium>=0.11->streamlit-folium) (0.4.2)
# Requirement already satisfied: requests in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from folium>=0.11->streamlit-folium) (2.25.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from jinja2>=2.9->folium>=0.11->streamlit-folium) (1.1.1)
# Requirement already satisfied: attrs in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.79->streamlit-folium) (20.3.0)
# Collecting base58
#   Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Collecting pyarrow
#   Downloading pyarrow-6.0.1-cp38-cp38-macosx_10_13_x86_64.whl (19.1 MB)
#      |████████████████████████████████| 19.1 MB 3.6 MB/s eta 0:00:01
# Collecting pympler>=0.9
#   Downloading Pympler-1.0.1-py3-none-any.whl (164 kB)
#      |████████████████████████████████| 164 kB 5.2 MB/s eta 0:00:01
# Requirement already satisfied: python-dateutil in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.79->streamlit-folium) (2.8.1)
# Collecting pydeck>=0.1.dev5
#   Downloading pydeck-0.7.1-py2.py3-none-any.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 807 kB/s eta 0:00:01
# Collecting tzlocal
#   Downloading tzlocal-4.1-py3-none-any.whl (19 kB)
# Collecting blinker
#   Downloading blinker-1.4.tar.gz (111 kB)
#      |████████████████████████████████| 111 kB 2.3 MB/s eta 0:00:01
# Collecting altair>=3.2.0
#   Downloading altair-4.2.0-py3-none-any.whl (812 kB)
#      |████████████████████████████████| 812 kB 2.8 MB/s eta 0:00:01
# Requirement already satisfied: packaging in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.79->streamlit-folium) (20.9)
# Collecting validators
#   Downloading validators-0.18.2-py3-none-any.whl (19 kB)
# Collecting gitpython!=3.1.19
#   Downloading GitPython-3.1.26-py3-none-any.whl (180 kB)
#      |████████████████████████████████| 180 kB 2.6 MB/s eta 0:00:01
# Requirement already satisfied: toml in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.79->streamlit-folium) (0.10.2)
# Collecting astor
#   Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Collecting protobuf!=3.11,>=3.6.0
#   Downloading protobuf-3.19.4-cp38-cp38-macosx_10_9_x86_64.whl (961 kB)
#      |████████████████████████████████| 961 kB 1.6 MB/s eta 0:00:01
# Requirement already satisfied: tornado>=5.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.79->streamlit-folium) (6.1)
# Requirement already satisfied: pandas>=0.21.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.79->streamlit-folium) (1.2.4)
# Collecting cachetools>=4.0
#   Downloading cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# Requirement already satisfied: click>=7.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.79->streamlit-folium) (7.1.2)
# Requirement already satisfied: pillow>=6.2.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from streamlit>=0.79->streamlit-folium) (8.2.0)
# Requirement already satisfied: entrypoints in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit>=0.79->streamlit-folium) (0.3)
# Requirement already satisfied: toolz in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit>=0.79->streamlit-folium) (0.11.1)
# Requirement already satisfied: jsonschema>=3.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from altair>=3.2.0->streamlit>=0.79->streamlit-folium) (3.2.0)
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.7 MB/s eta 0:00:01
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Requirement already satisfied: pyrsistent>=0.14.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.79->streamlit-folium) (0.17.3)
# Requirement already satisfied: setuptools in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.79->streamlit-folium) (52.0.0.post20210125)
# Requirement already satisfied: six>=1.11.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit>=0.79->streamlit-folium) (1.15.0)
# Requirement already satisfied: pytz>=2017.3 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.21.0->streamlit>=0.79->streamlit-folium) (2021.1)
# Requirement already satisfied: ipywidgets>=7.0.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (7.6.3)
# Requirement already satisfied: traitlets>=4.3.2 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (5.0.5)
# Requirement already satisfied: ipykernel>=5.1.2 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (5.3.4)
# Requirement already satisfied: jupyter-client in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (6.1.12)
# Requirement already satisfied: ipython>=5.0.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (7.22.0)
# Requirement already satisfied: appnope in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.1.2)
# Requirement already satisfied: decorator in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (5.0.6)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (3.0.17)
# Requirement already satisfied: pexpect>4.3 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (4.8.0)
# Requirement already satisfied: pickleshare in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.7.5)
# Requirement already satisfied: jedi>=0.16 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.17.2)
# Requirement already satisfied: pygments in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (2.8.1)
# Requirement already satisfied: backcall in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.2.0)
# Requirement already satisfied: nbformat>=4.2.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (5.1.3)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (3.5.1)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.0.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.7.0)
# Requirement already satisfied: jupyter-core in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (4.7.1)
# Requirement already satisfied: ipython-genutils in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.2.0)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from pexpect>4.3->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel>=5.1.2->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.2.5)
# Requirement already satisfied: notebook>=4.4.1 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (6.3.0)
# Requirement already satisfied: Send2Trash>=1.5.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.5.0)
# Requirement already satisfied: nbconvert in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (6.0.7)
# Requirement already satisfied: pyzmq>=17 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (20.0.0)
# Requirement already satisfied: terminado>=0.8.3 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.9.4)
# Requirement already satisfied: argon2-cffi in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (20.1.0)
# Requirement already satisfied: prometheus-client in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.10.1)
# Requirement already satisfied: cffi>=1.0.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.14.5)
# Requirement already satisfied: pycparser in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (2.20)
# Requirement already satisfied: defusedxml in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.1.2)
# Requirement already satisfied: testpath in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.4.4)
# Requirement already satisfied: mistune<2,>=0.8.1 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.4.3)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.5.3)
# Requirement already satisfied: bleach in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (3.3.0)
# Requirement already satisfied: async-generator in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.10)
# Requirement already satisfied: nest-asyncio in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from nbclient<0.6.0,>=0.5.0->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (1.5.1)
# Requirement already satisfied: webencodings in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets>=7.0.0->pydeck>=0.1.dev5->streamlit>=0.79->streamlit-folium) (0.5.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from packaging->streamlit>=0.79->streamlit-folium) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from requests->folium>=0.11->streamlit-folium) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from requests->folium>=0.11->streamlit-folium) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from requests->folium>=0.11->streamlit-folium) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from requests->folium>=0.11->streamlit-folium) (2020.12.5)
# Collecting pytz-deprecation-shim
#   Downloading pytz_deprecation_shim-0.1.0.post0-py2.py3-none-any.whl (15 kB)
# Collecting backports.zoneinfo
#   Downloading backports.zoneinfo-0.2.1-cp38-cp38-macosx_10_14_x86_64.whl (35 kB)
# Collecting tzdata
#   Downloading tzdata-2021.5-py2.py3-none-any.whl (339 kB)
#      |████████████████████████████████| 339 kB 3.4 MB/s eta 0:00:01
# Building wheels for collected packages: blinker
#   Building wheel for blinker (setup.py) ... done
#   Created wheel for blinker: filename=blinker-1.4-py3-none-any.whl size=13451 sha256=83aa0ec92b90fa45108e919b2ccc6b2e3332e6c96955727960d562fa1caf56ee
#   Stored in directory: /Users/ameliaingram/Library/Caches/pip/wheels/b7/a5/68/fe632054a5eadd531c7a49d740c50eb6adfbeca822b4eab8d4
# Successfully built blinker
# Installing collected packages: tzdata, smmap, backports.zoneinfo, pytz-deprecation-shim, gitdb, validators, tzlocal, pympler, pydeck, pyarrow, protobuf, gitpython, cachetools, blinker, base58, astor, altair, streamlit, streamlit-folium
# Successfully installed altair-4.2.0 astor-0.8.1 backports.zoneinfo-0.2.1 base58-2.1.1 blinker-1.4 cachetools-5.0.0 gitdb-4.0.9 gitpython-3.1.26 protobuf-3.19.4 pyarrow-6.0.1 pydeck-0.7.1 pympler-1.0.1 pytz-deprecation-shim-0.1.0.post0 smmap-5.0.0 streamlit-1.5.0 streamlit-folium-0.4.0 tzdata-2021.5 tzlocal-4.1 validators-0.18.2

# %%
import streamlit as st
from streamlit_folium import folium_static
import folium

# %%
# Create a Map instance
m = folium.Map(location=[40.6973,-74.1515], tiles='Stamen Toner',
                   zoom_start=10, control_scale=True)
print(m)
# Out:
# <folium.folium.Map object at 0x7fa21344deb0>

# %%
#Save the base map output
outfp = "base_map.html"

In [2]: m.save(outfp)

# %%
# Let's change the basemap style to 'Stamen Toner'
m2 = folium.Map(location=[40.6973,-74.1515], tiles='Stamen Toner',
                zoom_start=12, control_scale=True, prefer_canvas=True)

 # Filepath to the output
outfp2 = "/Users/ameliaingram/Documents/My_GitHub+Repository/base_map2.html"

# Save the map
m2.save(outfp2)

# %%
#Install Geopandas which will help us to use layers on the base map
import sys
# !{sys.executable} -m pip install geopandas #map layers visualization
# Out:
# Requirement already satisfied: geopandas in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (0.10.2)
# Requirement already satisfied: shapely>=1.6 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.8.0)
# Requirement already satisfied: fiona>=1.8 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.8.20)
# Requirement already satisfied: pyproj>=2.2.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (3.3.0)
# Requirement already satisfied: pandas>=0.25.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from geopandas) (1.2.4)
# Requirement already satisfied: munch in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2.5.0)
# Requirement already satisfied: attrs>=17 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (20.3.0)
# Requirement already satisfied: cligj>=0.5 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (0.7.2)
# Requirement already satisfied: click>=4.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (7.1.2)
# Requirement already satisfied: setuptools in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (52.0.0.post20210125)
# Requirement already satisfied: click-plugins>=1.0 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.1.1)
# Requirement already satisfied: certifi in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (2020.12.5)
# Requirement already satisfied: six>=1.7 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from fiona>=1.8->geopandas) (1.15.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (2021.1)
# Requirement already satisfied: numpy>=1.16.5 in /Users/ameliaingram/opt/anaconda3/lib/python3.8/site-packages (from pandas>=0.25.0->geopandas) (1.20.1)

# %%
import geopandas as gp
from folium.plugins import HeatMap
import pandas as pd
import numpy as np

# %%
# load the data
arrest_table = pd.read_csv("NYPD_Arrest_Data__Year_to_Date_.csv")

# %%
print(arrest_table.head())
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                   PD_DESC  KY_CD  \
# 0   234233843  09/29/2021  105.0         STRANGULATION 1ST  106.0
# 1   234129823  09/27/2021  157.0                    RAPE 1  104.0
# 2   234040747  09/25/2021  109.0  ASSAULT 2,1,UNCLASSIFIED  106.0
# 3   234047720  09/25/2021  101.0                 ASSAULT 3  344.0
# 4   234042526  09/25/2021  101.0                 ASSAULT 3  344.0
#
#                       OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# 0                FELONY ASSAULT  PL 1211200          F           B
# 1                          RAPE  PL 1303501          F           K
# 2                FELONY ASSAULT  PL 1200501          F           Q
# 3  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           B
# 4  ASSAULT 3 & RELATED OFFENSES  PL 1200001          M           B
#
#    ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX PERP_RACE  \
# 0               42                  0     25-44        M     BLACK
# 1               77                  0     25-44        M     BLACK
# 2              101                  0     25-44        M     BLACK
# 3               44                  0     25-44        M     BLACK
# 4               44                  0     25-44        M     BLACK
#
#    X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0     1009231      240290  40.826189 -73.909738
# 1     1003606      185050  40.674583 -73.930222
# 2     1049232      159210  40.603441 -73.765986
# 3     1006537      244511  40.837782 -73.919458
# 4     1007418      243859  40.835990 -73.916276
#
#                        New Georeferenced Column
# 0  POINT (-73.90973778899996 40.82618898100003)
# 1  POINT (-73.93022154099998 40.67458330800008)
# 2  POINT (-73.76598558899997 40.60344094100003)
# 3  POINT (-73.91945797099999 40.83778161800007)
# 4  POINT (-73.91627635999998 40.83598980000005)

# %%
#pull locations from the table to determine the starting geopoint
locations = arrest_table[['Latitude', 'Longitude']]
locationlist = locations.values.tolist()
len(locationlist)
locationlist[7]
# Out:
# [40.81038342800008, -73.90452841699994]

# %%
# start the map of New York using the latitude and longitude from locations
map_osm = folium.Map(location=[40.81, -73.90], zoom_start=11)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7f2e8f862ba4425abd56960c4292f6df%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7f2e8f862ba4425abd56960c4292f6df%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7f2e8f862ba4425abd56960c4292f6df%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7f2e8f862ba4425abd56960c4292f6df%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.81%2C%20-73.9%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %%
#Now we will work with the Race and take a sample of 1K observations.
arrest_table = arrest_table.sample(n=1000, replace=False, random_state=1)
arrest_table.dropna(subset=['PERP_RACE'],inplace=True)

#We will create a function to produce a heatmap based on race
def race_col(x):
  if x=='BLACK':
    return 'black'
  if x=='WHITE':
    return 'blue'
  if x=='ASIAN':
    return 'yellow'
  if x=='HISPANIC':
    return 'red'
  else:
    return 'green'
arrest_table['color_race'] = arrest_table['PERP_RACE'].apply(lambda x:race_col(x) )

# Create the Heat Map
#Make the list of Lat an Long
lat = arrest_table.Latitude.tolist()
lng = arrest_table.Longitude.tolist()
HeatMap(list(zip(lat, lng))).add_to(map_osm)

# Add the Circles with the corresponding races based on the color
arrest_table.apply(lambda x:folium.Circle(location=[x['Latitude'], x['Longitude']], radius=50, fill=True, color=x['color_race'], popup=x['AGE_GROUP']).add_to(map_osm), axis=1)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_7f2e8f862ba4425abd56960c4292f6df%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium%40master/folium/templates/leaflet_heat.min.js%22%3E%3C/script%3E%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_7f2e8f862ba4425abd56960c4292f6df%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_7f2e8f862ba4425abd56960c4292f6df%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_7f2e8f862ba4425abd56960c4292f6df%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%2 ...

# %% [markdown]
# <h3>Success!</h3>
# <p>The result generated a heatmap of a 1000 person sample of arrests, sorted by race.  The individual points are arrests that are color coded by race, and will pop up with age.  </p>
# <p>I still have a lot to learn on this technique (and mapping in general)...but I made some progress and it was a lot of fun!</p>

# %% [markdown]
# <h3>Sources Used in this Project:</h3><a id=7></a>
# NYC Open Data.  <a>https://opendata.cityofnewyork.us/</a><br>
# Pipis, George.  2021.  How to Make Interactive Maps with Folium.  Python-bloggers.com <a>https://python-bloggers.com/2021/06/how-to-make-interactive-maps-with-folium/ </a><br>
# Silva, George.  2017.  Mapping Points with Folium.  <a>https://georgetsilva.github.io/posts/mapping-points-with-folium/</a><br>
# Tenkanen, Henrikki.  2016. GeoPython and ArcGIS. Fall 2016 course materials.  University of Helsinki.  <a>https://automating-gis-processes.github.io/2016/course-info.html#</a> <br>

# %% [markdown]
# [Back to top](#1)
